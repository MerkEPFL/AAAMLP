# %%
import pandas as pd
import os
import seaborn as sns

# %%
print(os.getcwd())
# Out:
# /Users/Samuele 1/Documents/GitHub/AAAMLP/categorical_variables/notebooks

# %%
df = pd.read_csv("../input/train_folds.csv")

# %%
sns.countplot(x='kfold', data=df)

# %% [markdown]
# ## Let's check if stratified kfold worked

# %%
folds = df.kfold.unique()
for fold in folds:
    print(f"Fold: {fold}")
    print(df[df.kfold==fold].target.value_counts())
# Out:
# Fold: 0
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 1
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 2
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 3
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 4
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 5
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 6
# 0    48768
# 1    11232
# Name: target, dtype: int64
# Fold: 7
# 0    48767
# 1    11233
# Name: target, dtype: int64
# Fold: 8
# 0    48767
# 1    11233
# Name: target, dtype: int64
# Fold: 9
# 0    48767
# 1    11233
# Name: target, dtype: int64
